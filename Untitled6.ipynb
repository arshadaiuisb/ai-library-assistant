# %% [markdown]
# <a href="https://colab.research.google.com/github/arshadaiuisb/ai-library-assistant/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# %cd /content/Wav2Lip
# !pip install -q librosa==0.9.2
# !wget -q "https://huggingface.co/numz/wav2lip_studio/resolve/main/Wav2lip/wav2lip_gan.pth" \
    -O checkpoints/wav2lip_gan.pth
# !wget -q "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" \
    -O face_detection/detection/sfd/s3fd.pth
print("✅ Setup complete!")
# Out:
# fatal: destination path 'Wav2Lip' already exists and is not an empty directory.
# /content
# ✅ Setup complete!

# %%
# !pip install -q numpy==1.23.5 opencv-python==4.5.5.64 --force-reinstall
# Out:
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import os
os.kill(os.getpid(), 9)

# %%
from google.colab import files
uploaded = files.upload()
# Select BOTH face.jpg and audio.mp3 when prompted
# Out:
#      <input type="file" id="files-2a962193-5403-4855-b729-3cc72034ae06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a962193-5403-4855-b729-3cc72034ae06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import shutil, os
os.makedirs('/content/Wav2Lip/results', exist_ok=True)
shutil.copy('face.jpg', '/content/Wav2Lip/face.jpg')
shutil.copy('audio.mp3', '/content/Wav2Lip/audio.mp3')
print("✅ Files ready!")
# Out:
# ✅ Files ready!

# %%
os.chdir('/content/Wav2Lip')
# !python inference.py \
  --checkpoint_path checkpoints/wav2lip_gan.pth \
  --face face.jpg \
  --audio audio.mp3 \
  --outfile results/result.mp4
# Out:
# Using cpu for inference.
# Number of frames available for inference: 1
# Extracting raw audio...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
